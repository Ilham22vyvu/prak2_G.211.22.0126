# %%
# Tuple
mahasiswa = ("G.211.22.0126", "Ilham Triatmaja", 19)
print("Data Mahasiswa:")
print("NIM:", mahasiswa[0])
print("Nama:", mahasiswa[1])
print("Usia:", mahasiswa[2])

# Dictionary
mahasiswa_dict = {"NIM": "G.211.22.0126", "Nama": "Ilham Triatmaja", "Usia": 19}
print("\nData Mahasiswa (Dictionary):")
print("NIM:", mahasiswa_dict["NIM"])
print("Nama:", mahasiswa_dict["Nama"])
print("Usia:", mahasiswa_dict["Usia"])
# Out:
# Data Mahasiswa:
# NIM: G.211.22.0126
# Nama: Ilham Triatmaja
# Usia: 19
#
# Data Mahasiswa (Dictionary):
# NIM: G.211.22.0126
# Nama: Ilham Triatmaja
# Usia: 19

# %%
# Tuple
mahasiswa = ("000456", "bryan ", 21)

# Mengakses elemen Tuple
nim = mahasiswa[0]
nama = mahasiswa[1]
usia = mahasiswa[2]

# Menampilkan informasi mahasiswa
print("Data Mahasiswa:")
print("NIM:", nim)
print("Nama:", nama)
print("Usia:", usia)
# Out:
# Data Mahasiswa:
# NIM: 000456
# Nama: bryan
# Usia: 21

# %%
# Dictionary
mahasiswa_dict = {"NIM": "000456", "Nama": "bryan", "Usia": 21}

# Mengakses nilai Dictionary
nim_dict = mahasiswa_dict["NIM"]
nama_dict = mahasiswa_dict["Nama"]
usia_dict = mahasiswa_dict["Usia"]

# Menampilkan informasi mahasiswa dari Dictionary
print("\nData Mahasiswa (Dictionary):")
print("NIM:", nim_dict)
print("Nama:", nama_dict)
print("Usia:", usia_dict)
# Out:
# Data Mahasiswa (Dictionary):
# NIM: 000456
# Nama: bryan
# Usia: 21
